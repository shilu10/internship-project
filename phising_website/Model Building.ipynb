# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
import pickle

# %%
main_df = pd.read_csv("preprocessed_files_from_db/preprocessed_data.csv")

# %%
main_df
# Out:
#        qty_slash_url  length_url  qty_dot_domain  qty_dot_directory  \
# 0                  1          25               2                  1
# 1                  3         223               2                  3
# 2                  1          15               2                  0
# 3                  5          81               2                  2
# 4                  0          19               2                 -1
# ...              ...         ...             ...                ...
# 88642              0          23               3                 -1
# 88643              0          34               2                 -1
# 88644              5          70               1                  1
# 88645              1          28               2                  0
# 88646              0          16               2                 -1
#
#        qty_hyphen_directory  qty_underline_directory  qty_slash_directory  \
# 0                         0                        0                    1
# 1                         0                        0                    3
# 2                         0                        0                    1
# 3                         0                        2                    5
# 4                        -1                       -1                   -1
# ...                     ...                      ...                  ...
# 88642                    -1                       -1                   -1
# 88643                    -1                       -1                   -1
# 88644                     1                        0                    5
# 88645                     0                        0                    1
# 88646                    -1                       -1                   -1
#
#        qty_questionmark_directory  qty_and_directory  qty_space_directory  \
# 0                               0                  0                    0
# 1                               0                  0                    0
# 2                               0                  0                    0
# 3                               0                  0                    0
# 4                              -1                 -1                   -1
# ...                           ...                ...                  ...
# 88642                          -1                 -1                   -1
# 88643                          -1                 -1                   -1
# 88644                           0                  0                    0
# 88645                           0                  0                    0
# 88646                          -1                 -1                   -1
#
#        ...  qty_plus_params  qty_asterisk_params  qty_dollar_params  \
# 0      ...               -1                   -1                 -1
# 1      ...                0                    0                  0
# 2      ...               -1                   -1                 -1
# 3      ...               -1                   -1                 -1
# 4      ...               -1                   -1                 -1
# ...    ...              ...                  ...                ...
# 88642  ...               -1                   -1                 -1
# 88643  ...               -1                   -1                 -1
# 88644  ...               -1                   -1                 -1
# 88645  ...               -1                   -1                 -1
# 88646  ...               -1                   -1                 -1
#
#        qty_percent_params  qty_params  asn_ip  time_domain_activation  \
# 0                      -1          -1   60781                      -1
# 1                       0           3   36024                     579
# 2                      -1          -1    4766                      -1
# 3                      -1          -1   20454                      -1
# 4                      -1          -1   53831                    6998
# ...                   ...         ...     ...                     ...
# 88642                  -1          -1    8560                    5509
# 88643                  -1          -1   26496                    5046
# 88644                  -1          -1  394695                    1844
# 88645                  -1          -1   47583                      -1
# 88646                  -1          -1   47846                     300
#
#        ttl_hostname  cluster_labels  labels
# 0               892               2       1
# 1              9540               2       1
# 2               589               0       0
# 3               292               0       1
# 4              3597               2       0
# ...             ...             ...     ...
# 88642          3597               0       0
# 88643           591               0       0
# 88644         14391               1       1
# 88645            52               2       1
# 88646           299               2       0
#
# [88647 rows x 52 columns]

# %%
clusters = main_df.cluster_labels.unique()

# %%
clusters
# Out:
# array([2, 0, 1])

# %%
cluster_dic = {}
for cluster in clusters: 
    cluster_dic["df_"+str(cluster)] = pd.DataFrame(main_df[main_df.cluster_labels==cluster])

# %%
cluster_dic["df_0"].drop("cluster_labels", inplace=True, axis=1)

# %%
cluster_dic["df_1"].drop("cluster_labels", inplace=True, axis=1)

# %%
cluster_dic["df_2"].drop("cluster_labels", inplace=True, axis=1)

# %%
with open("objects/selected_cols.obj", 'rb') as f: 
    selected_cols = pickle.load(f)

# %%
models_params_dict = {
    "rf_classifier": {
        "object": RandomForestClassifier(), 
        "params": {
            "criterion": ["gini", "entropy"],
            "n_estimators": [100, 150, 200],
            "max_depth": [20, 40, 60], 
            "oob_score": [True],
            
            "random_state": [32],
            
        }
    }, 
    "gb_classifier": {
        "object": GradientBoostingClassifier(), 
        "params": {
            "loss": ["exponential"],
            "n_estimators": [100, 150, 200],
            "criterion": ["friedman_mse", "squared_error"], 
            "max_depth": [3, 6, 9], 
            "random_state": [32], 
            
        }
    }
}

# %%
result = {
    
}

for cluster_no, cluster_df in cluster_dic.items(): 
   
    for classifier in models_params_dict: 
        print(classifier)
        grid_search_cv = GridSearchCV(models_params_dict[classifier].get("object"), models_params_dict[classifier].get("params"), n_jobs=15)
        grid_search_cv.fit(cluster_df[(selected_cols)], cluster_df.labels)
        if not result.get(cluster_no): 
            result[cluster_no] = {}
            result[cluster_no][classifier] = {}
        result[cluster_no][classifier]["best_params"] = grid_search_cv.best_params_
        result[cluster_no][classifier]["best_score"] = grid_search_cv.best_score_
        print(result)
# Out:
# rf_classifier
# {'df_2': {'rf_classifier': {'best_params': {'criterion': 'entropy', 'max_depth': 40, 'n_estimators': 150, 'oob_score': True, 'random_state': 32}, 'best_score': 0.9706274355365558}}}
# gb_classifier
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-b1d48eeaa1e2> in <module>
#      12             result[cluster_no] = {}
#      13             result[cluster_no][classifier] = {}
# ---> 14         result[cluster_no][classifier]["best_params"] = grid_search_cv.best_params_
#      15         result[cluster_no][classifier]["best_score"] = grid_search_cv.best_score_
#      16         print(result)
#
# KeyError: 'gb_classifier'

# %%
result
# Out:
# {}
